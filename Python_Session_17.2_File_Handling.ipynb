# %% [markdown]
# # 05 Aug 2024----

# %% [markdown]
# ## USING WITH keyword
#
# - When we open and Read  in different lnes
#
# - Python indirectly take the session approach
#
# - The session will close after some time
#
# - The stored data will not be able to use(its gone)
#
# - We need t perform same operations under same operations
#
# - By using with keyword

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\Documents\\NARESHIT\\CLASSROOM NOTES'

# %%
pa = 'mbox-short.txt'
file=open(pa)
d = file.read()
print(d)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
# Using with option

pa = 'mbox-short.txt'
# file=open(pa)
# d = file.read()
with open(pa) as file:
    data = file.read()

print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# # Encodeing

# %% [markdown]
# - Encoding is a method , to hide the characters for security purpose
#
# - Whenever we read some files we have some special charatcters
#
# - To avoid those we will use encodeing argument while open the file path
#
# - We have so many encoding methods
#
# - **utf-8-sig** is one of the main encoding method
#
# **Mode**
#
# - While openiing the file there is a mode argument
#
# - By default mode = 'r' which means read
#
# - if you want write mode use = 'w'
#
# ** file not found error **
#
# - File not found error means , file is not available is the given path
#
# - This is completely our jon : this error is due to our mistake
#
# - Go to that path , check the file name in that location
#
#
# ** permission Error **
#
# - The file we are using in Python is already open in your laptop
#
# - You might be able to see or it might be open but inviible or openin background under some app
#
# - If you are able to see the close manually
#
# - If you are not able to see and close , then restart the laoptop
#
# - Again only open the jupyter notebook
#
# -

# %%
pa = 'mbox-short.txt'
# file=open(pa)
# d = file.read()
with open(pa) as file:
    data = file.read()

print(data)

USE ENCODING IN THIS CELL
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# # Write the file

# %%
 # take Method - 2

pa = 'mbox-short.txt'
file=open(pa)
d = file.read()

# %% [markdown]
# - Write the file also same way like read the file
#
# - **Check point number - 1**
#
# - What is the file name , which you want to write something
#
# - Is that file existed in your laptop or not
#
# - Generally we will give the new name , That is not existed in your laptop
#
# ** Check pont number - 2 **
#
# - Choose the correct mode
#
# - For writting we ha emany modes
#
#     - mode = 'w' : Clear the existed data and overwrite with new data
#
#     - mode = 'a' : Dont want to clear the old data ,new data append with old data
#
# ** Check point number 3 **
#
# - For reading we will use 'read'
#
# - For writting we will use 'write'

# %%
pa = 'SJ_NEW FILE.txt'
file=open(pa,mode='w')
d = file.write('SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE.TXT')
print(d)
# Out:
# 54

# %%
pa = 'SJ_NEW FILE.txt'
file=open(pa)
d = file.read()
print(d)
# Out:
# SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE.TXT

# %%
pa = 'SJ_NEW FILE22222222.txt'
file=open(pa,mode='w')
d = file.write('SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE222222.TXT')

# %%
pa = 'SJ_NEW FILE3333.txt'
file=open(pa,mode='w')
d = file.write('SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE333.TXT')

# %%
pa = 'SJ WITH OPEN.txt'
# file=open(pa)
# d = file.read()
with open(pa,mode='w') as file:
    data = file.write('Sample Data written with WITH OPEN Method')

# %% [markdown]
# # Itterating each line using For loops

# %%
path='mbox-short.txt'
file = open(path)
Data = file.read()
for i in Data:
    print(i)

# %%
path='mbox-short.txt'
file = open(path)
Data = file.read()
for i in Data.split():
    print(i)

# %%
path='mbox-short.txt'
file = open(path)
Data = file.read()
for i in Data.split('/n'):
    print(i)

# %%
pa = 'mbox-short.txt'
# file=open(pa)
# d = file.read()
with open(pa,mode='r',encoding = 'utf-8-sig') as file:
    data = file.read()
    for i in data.split('\n'):
        print(i)

# %% [markdown]
# # You want to save output in different Folder but in same root directory

# %%
pa = r'C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\OUTPUT FOLDER\SJ_NEW FILE.txt'
file=open(pa,mode='w')
d = file.write('SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE333.TXT')

# %% [markdown]
# - Here we created manuaaaly a folder named "OUTPUT FOLDER"
#
# - This Folder is same python root Directory
#
# - python root directory is:
#
#     - Documents\NARESHIT\CLASSROOM NOTES\
#
# - Output Root directory is :
#
#     - Documents\NARESHIT\CLASSROOM NOTES\OUTPUT FOLDER\
#
# - Whenever in this we no need to create a folder manually
#
# - we will create a folder by using **OS** package

# %%
import os
os.getcwd()
cwd = os.getcwd()

finalpath = cwd+'\OUTPUT FOLDER'
print(finalpath)
# Out:
# C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\OUTPUT FOLDER

# %% [markdown]
# # 2nd menthod

# %%
import os
os.getcwd()
cwd = os.getcwd()
folder_name = 'OUTPUT FOLDER'
finalpath = cwd+'\\'+folder_name
print(finalpath)
# Out:
# C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\OUTPUT FOLDER

# %% [markdown]
# # 3 Ways to concatenate folder

# %%
folder_name = 'OUTPUT FOLDER'
os.getcwd()+'\\'+folder_name # working (Average)
os.getcwd()+'/'+folder_name # Not better 
os.getcwd()+f."\{folder_name}"# working (hit)

# best practise

os.path.join(os.getcwd(),folder_name)

# %%
current_path = os.getcwd()
folder_name = 'OUTPUT'
new_dir=os.path.join(current_path,folder_name)
os.makedirs(new_dir)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO\\Documents\\NARESHIT\\CLASSROOM NOTES'

# %%
try:
    current_path = os.getcwd()
    folder_name = 'OUTPUT2'
    new_dir=os.path.join(current_path,folder_name)
    os.makedirs(new_dir)

except exception as e:
    print(e)

# %%
newfoldername = 'OUTPUT3'
filename = 'newfile.txt'
path = os.path.join(os.getcwd() ,newfoldername)
# file=open(pa,mode='w')
# d = file.write('SAMPLE TEXT WRIITEN INSUDE A FILE NAME SJ_NEW FILE333.TXT')
print(path)
# Out:
# C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\OUTPUT3

# %%
newfoldername = 'OUTPUT2'
filename = 'newfile.txt'
path = os.path.join(os.getcwd() ,newfoldername)
print(path)
# Out:
# C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\OUTPUT2

# %%
- Step 1  : Create a d Folder

- step 2 : To create  a folder we will use : os.makedir()

- step 3 : os.makedirs will take full path

    - the path is full folder path

    - imagine that if you create  a folder what is the full path

    - c: users\\........................\\newfoldername

- step 4 : Again in this we have two things

    - Current working directory

    - folder name

    - we are telling python you concatenate both

- step 5 : os.path.join will concatenate the both current working dir , folder name

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\LENOVO\\Documents\\NARESHIT\\CLASSROOM NOTES'

# %%
cwd = os.getcwd()
print("cwd :: " , cwd)
foldername = 'NEWSJ'
newpath=os.path.join(cwd,foldername)
print("newpath" , newpath)
os.makedirs(newpath)
############
#newpath C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES\NEWSJ --- this is the full new path where we want to create a fle 

# newfilename = 'SJ2.txt'
# finalpath = os.path.join(newpath,newfilename)
# with open(finalpath,mode='w') as file:
#     file.write('this is a new file made by concatenating the new folder and new file name')

# %%
import os
newfilename = 'SJ2.txt'
finalpath = os.path.join(newpath,newfilename)
with open(finalpath,mode='w') as file:
    file.write('this is a new file made by concatenating the new folder and new file name')

# %%
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\LENOVO\Documents\NARESHIT\CLASSROOM NOTES

# %%
# Q1.) Find the number of linesin mbox-short file
import os
path = 'mbox-short.txt'
file=open(path)
# data = file.read()
# print(data)

# for i in data:
#     print(i) #this will print each in every character
count = 0
for i in file:
    count=count+1

print(count)
# Out:
# 1909

# %% [markdown]
# # ENUMERATE

# %% [markdown]
# - Enumerate is the in-built function like zip
#
# - It will give two values
#
#     - Index of the line
#     - Actual  Line

# %%
import os

path = 'mbox-short.txt'
file=open(path)

for i,j  in enumerate(file):
    pass
    # print('n')
    #count=count+1
    # here in i it will save index and j will store the actual line content
    # print(i)
print(i+1)
# Out:
# 1910

# %%
import os
path = 'mbox-short.txt'
file=open(path)

for i,_  in enumerate(file):
    pass
    # print('n')
    #count=count+1
    # here in i it will save index and j will store the actual line content
    # print(i)
print(i+1)
# Out:
# 1910

# %% [markdown]
# - whenever we defined one variable
#
# - that variable is not being used or we dont want to use
#
# - without that variable the code will not work
#
# - that variable we can replace with _ (underscore)

# %%
# Q2.) When you read the data , some of the lines are not alligned ?

path = 'mbox-short.txt'
file = open(path)

for line in file:
    print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %%
# Q3.) I want lines that are starting with 'from' and save in a list and get the no of lines

path = 'mbox-short.txt'
file = open(path)
from_list=[]
for line in file:
    if line.startswith('From'):
        print(line)
        from_list.append(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# From: stephen.marquard@uct.ac.za
#
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
#
# From: louis@media.berkeley.edu
#
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
#
# From: rjlowe@iupui.edu
#
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
#
# From: zqian@umich.edu
#
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
#
# From: rjlowe@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
#
# From: cwen@iupui.edu
#
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
#
# From: cwen@iupui.edu
#
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
#
# From: gsilver@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
#
# From: gsilver@umich.edu
#
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
#
# From: zqian@umich.edu
#
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
#
# From: gsilver@umich.edu
#
# ...

# %%
path='mbox-short.txt'
file = open(path)
from_list = [line for line in file if line.startswith('From')]
len(from_list)
# Out:
# 54

# %%
from_list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\n',
#  'From: stephen.marquard@uct.ac.za\n',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008\n',
#  'From: louis@media.berkeley.edu\n',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008\n',
#  'From: zqian@umich.edu\n',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008\n',
#  'From: rjlowe@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008\n',
#  'From: cwen@iupui.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008\n',
#  'From: gsilver@umich.edu\n',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008\n',
#  'From: zqian@umich.edu\n',
# ...

# %%
# Q4.) Remove \n from end from above output
# take above output as input
# itterate  and apply rstrip
# keep in another list
from_list3=[]
from_list2 = from_list
for line in from_list2:
    from_list3.append(line.rstrip('\n'))

from_list3
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
path='mbox-short.txt'
file = open(path)
from_list = [line.rstrip('\n') for line in file if line.startswith('From')]
len(from_list)
# Out:
# 54

# %% [markdown]
# - Q5.) Extract only the Emails from from_list3
# - Q6.) Unique Emails
# - Q7.) You need to read the text file - first Name , last name , emails , all companies
